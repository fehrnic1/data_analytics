# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3465, 277)
#    type        id        lat       lon tags.addr:city tags.addr:country  \
# 0  node  33126515  47.155616  9.037915        Schänis                CH
# 1  node  36726161  47.226191  8.980329         Uznach               NaN
# 2  node  39768209  47.225154  8.969868         Uznach               NaN
# 3  node  39947904  47.376732  8.542161         Zürich                CH
# 4  node  48932835  47.375020  8.522895         Zürich               NaN
#
#   tags.addr:housenumber tags.addr:postcode tags.addr:street tags.brand  ...  \
# 0                    32               8718   Biltnerstrasse       Spar  ...
# 1                    25               8730   Zürcherstrasse     Migros  ...
# 2                   NaN               8730              NaN       Coop  ...
# 3                     1               8001    Bahnhofbrücke       Coop  ...
# 4                     7               8004     Wengistrasse     Migros  ...
#
#   tags.postid tags.diet:local tags.payment:account_cards  \
# 0         NaN             NaN                        NaN
# 1         NaN             NaN                        NaN
# 2         NaN             NaN                        NaN
# 3         NaN             NaN                        NaN
# 4         NaN             NaN                        NaN
#
#   tags.diet:mediterranean tags.diet:organic tags.diet:seafood  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#   tags.recycling:low_energy_bulbs tags.opening_hours:cafe tags.name:zh-Hans  \
# 0                             NaN                     NaN               NaN
# 1                             NaN                     NaN               NaN
# 2                             NaN                     NaN               NaN
# 3                             NaN                     NaN               NaN
# 4                             NaN                     NaN               NaN
#
#   tags.panoramax
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 277 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 6  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_304fc9eb96fc3702681bdac779ee09dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_304fc9eb96fc3702681bdac779ee09dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_304fc9eb96fc3702681bdac779ee09dd = L.map(
#                 &quot;map_304fc9eb96fc3702681bdac779ee09dd&quot;,
#                 {
#                     center: [47.00906173693322, 8.004165308079141],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_304fc9eb96fc3702681bdac779ee09dd);
#
#
#
#
#
#             var tile_layer_d9ac6d04ddea04fff3bf3e7731c55a24 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d9ac6d04ddea04fff3bf3e7731c55a24.addTo(map_304fc9eb96fc3702681bdac779ee09dd);
#
#
#             var marker_73f1d2c1f1d70869c1b4d4cc199c5429 = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_304fc9eb96fc3702681bdac779ee09dd);
#
#
#         var popup_5a752d557089007eedd3bafc98e83c0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6811189795a8fb1be010e4ccd89c1d8 = $(`&lt;div id=&quot;html_d6811189795a8fb1be010e4ccd89c1d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_5a752d557089007eedd3bafc98e83c0a.setContent(html_d6811189795a8fb1be010e4ccd89c1d8);
#
#
#
#         marker_73f1d2c1f1d70869c1b4d4cc199c5429.bindPopup(popup_5a752d557089007eedd3bafc98e83c0a)
#         ;
#
#
#
#
#             var marker_74bc7a20f6c3fc0a3ac7627ace6997c6 = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_304fc9eb96fc3702681bdac779ee09dd);
#
#
#         var popup_e1a70eace193dc6cbda034435089b1e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ee8a08a19a5ab3d35a9ee486c7a8742 = $(`&lt;div id=&quot;html_8ee8a08a19a5ab3d35a9ee486c7a8742&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_e1a70eace193dc6cbda034435089b1e2.setContent(html_8ee8a08a19a5ab3d35a9ee486c7a8742);
#
#
#
#         marker_74bc7a20f6c3fc0a3ac7627ace6997c6.bindPopup(popup_e1a70eace193dc6cbda034435089b1e2)
#         ;
#
#
#
#
#             var marker_8ecf9aa49d774d09103d9a72427a178e = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_304fc9eb96fc3702681bdac779ee09dd);
#
#
#         var popup_1d5b09b3c1eeb9f8bd3402826391a77d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_55ea2e34c00f87956e5fb87eab6f0701 = $(`&lt;div id=&quot;html_55ea2e34c00f87956e5fb87eab6f0701&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_1d5b09b3c1eeb9f8bd3402826391a77d.setContent(html_55ea2e34c00f87956e5fb87eab6f0701);
#
#
#
#         marker_8ecf9aa49d774d09103d9a72427a178e.bindPopup(popup_1d5b09b3c1eeb9f8bd3402826391a77d)
#         ;
#
#
#
#
#             var marker_733d3b236f2f1ca7e442308a9f8ca3b8 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_304fc9eb96fc3702681bdac779ee09dd);
#
#
#         var popup_0247631815fe8c2ad023fdc27c6a89e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d95d2253114d1170ef59ed66ccde6b7f = $(`&lt;div id=&quot;html_d95d2253114d1170ef59ed66ccde6b7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_0247631815fe8c2ad023fdc27c6a89e6.setContent(html_d95d2253114d1170ef59ed66ccde6b7f);
#
#
#
#         marker_733d3b236f2f1ca7e442308a9f8ca3b8.bindPopup(popup_0247631815fe8c2ad023fdc27c6a89e6)
#         ;
#
#
#
#
#             var marker_3e3f58698ec3a54833bc2fcc3ab3cf29 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_304fc9eb96fc3702681bdac779ee09dd);
#
#
#         var popup_39766390ad7dbdd2529bc5e496382935 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bfdac4d1d9a24a940d4ecd467126154 = $(`&lt;div id=&quot;html_1bfdac4d1d9a24a940d4ecd467126154&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_39766390ad7dbdd2529bc5e496382935.setContent(html_1bfdac4d1d9a24a940d4ecd467126154);
#
#
#
#         marker_3e3f58698ec3a54833bc2fcc3ab3cf29.bindPopup(popup_39766390ad7dbdd2529bc5e496382935)
#         ;
#
#
#
#
#             var marker_1a48a8946dcf93c884732ee33204f126 = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-09-29 13:53:11
# Python Version: 3.11.13
# -----------------------------------
